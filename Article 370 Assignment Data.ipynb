# %% [markdown]
# # Overview

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# %%
#Article 1 on Article 370: Abrogation & Reorganization will Open the Doors of Development in Kashmir & Laddakh

# %%
url='https://www.mbauniverse.com/group-discussion/topic/current-affairs/article-370'
response=requests.get(url)

# %%
soup_dos = BeautifulSoup(response.content,'html.parser')

# %%
doc_text=soup_dos.get_text()

# %%
doc_text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\nvar _smartsupp = _smartsupp || {};\n_smartsupp.key = \'9fe3d96ceb558a64768e8a82485dccbb0f6e7039\';\nwindow.smartsupp||(function(d) {\n\tvar s,c,o=smartsupp=function(){ o._.push(arguments)};o._=[];\n\ts=d.getElementsByTagName(\'script\')[0];c=d.createElement(\'script\');\n\tc.type=\'text/javascript\';c.charset=\'utf-8\';c.async=true;\n\tc.src=\'//www.smartsuppchat.com/loader.js?\';s.parentNode.insertBefore(c,s);\n})(document);\n\n\n\n\n\n\nGD Topic: Article 370 - Abrogation & Reorganization will Open the Doors of Development in Kashmir & Laddakh\n\n\n\n\n\n\n\n<!--/*--><![CDATA[/*><!--*/\n#backtotop{left:50%;margin-left:-50px;}\n\n/*]]>*/-->\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<!--//--><![CDATA[//><!--\n(function(i,s,o,g,r,a,m){i["GoogleAnalyticsObject"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,doc
# ...

# %%
#Article 2 on Article 370 Scrapped: Effects On Travel In Jammu & Kashmir, And Ladakh

# %%
url1='https://traveltriangle.com/blog/travel-to-kashmir-after-article-370-scrapped/'
response=requests.get(url1)
soup_dos1 = BeautifulSoup(response.content,'html.parser')
doc_text1=soup_dos1.get_text()
doc_text1
# Out:
# '\n\n\n\n\n\n\n\n\nArticle 370 Scrapped: Effects On Travel In Jammu & Kashmir, And Ladakh |\n\n\n\n\n\n\n\n/*! jQuery v1.11.3 | (c) 2005, 2015 jQuery Foundation, Inc. | jquery.org/license */\n!function(a,b){"object"==typeof module&&"object"==typeof module.exports?module.exports=a.document?b(a,!0):function(a){if(!a.document)throw new Error("jQuery requires a window with a document");return b(a)}:b(a)}("undefined"!=typeof window?window:this,function(a,b){var c=[],d=c.slice,e=c.concat,f=c.push,g=c.indexOf,h={},i=h.toString,j=h.hasOwnProperty,k={},l="1.11.3",m=function(a,b){return new m.fn.init(a,b)},n=/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g,o=/^-ms-/,p=/-([\\da-z])/gi,q=function(a,b){return b.toUpperCase()};m.fn=m.prototype={jquery:l,constructor:m,selector:"",length:0,toArray:function(){return d.call(this)},get:function(a){return null!=a?0>a?this[a+this.length]:this[a]:d.call(this)},pushStack:function(a){var b=m.merge(this.constructor(),a);return b.prevObject=this,b.context=this.cont
# ...

# %%
#Artcile 3 Indian Defence Review

# %%
url2='http://www.indiandefencereview.com/spotlights/impact-of-article-370/'
response=requests.get(url2)
soup_dos2 = BeautifulSoup(response.content,'html.parser')
doc_text2=soup_dos2.get_text()
doc_text2
# Out:
# '\n\n\n\n\n\n\n\n\n\n\nImpact of Article 370 - Indian Defence Review\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"http://www.indiandefencereview.com/#organization","name":"Indian Defence Review (IDR), quarterly journal, the brainchild of former captain of the Indian Army, was launched on January 1, 1986 as a logical continuum to Lancer established in 1979, the first Indian publishing house dedicated to put forward the military experience and point of view.","url":"http://www.indiandefencereview.com/","sameAs":[],"logo":{"@type":"ImageObject","@id":"http://www.indiandefencereview.com/#logo","url":"http://www.indiandefencereview.com/wp-content/uploads/2018/08/favicon.ico","caption":"Indian Defence Review (IDR), quarterly journal, the brainchild of former captain of the Indian Army, was launched on January 1, 1986 as a logical continuum to Lancer established in 1979, the first Indian publishing house dedicated to put forwar
# ...

# %%
#Article on Price Affect on Kashmir

# %%
url3='http://www.indiandefencereview.com/spotlights/impact-of-article-370/'
response=requests.get(url3)
soup_dos3 = BeautifulSoup(response.content,'html.parser')
doc_text3=soup_dos3.get_text()
doc_text3
# Out:
# '\n\n\n\n\n\n\n\n\n\n\nImpact of Article 370 - Indian Defence Review\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n{"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"http://www.indiandefencereview.com/#organization","name":"Indian Defence Review (IDR), quarterly journal, the brainchild of former captain of the Indian Army, was launched on January 1, 1986 as a logical continuum to Lancer established in 1979, the first Indian publishing house dedicated to put forward the military experience and point of view.","url":"http://www.indiandefencereview.com/","sameAs":[],"logo":{"@type":"ImageObject","@id":"http://www.indiandefencereview.com/#logo","url":"http://www.indiandefencereview.com/wp-content/uploads/2018/08/favicon.ico","caption":"Indian Defence Review (IDR), quarterly journal, the brainchild of former captain of the Indian Army, was launched on January 1, 1986 as a logical continuum to Lancer established in 1979, the first Indian publishing house dedicated to put forwar
# ...

# %% [markdown]
# # Land Price

# %%
import PyPDF2

# %%
object = open('McGraw.Hill.Osborne.Media.OCA.Oracle.Database.11g.SQL.Fundamentals.I.Exam.Guide.Exam.1Z0-051.May. (1).pdf','rb')

# %%
reader=PyPDF2.PdfFileReader(object)

# %%
reader.numPages
# Out:
# 606

# %%
page = reader.getPage(11)
page.extractText()
# Out:
# ''

# %%
#Not Working

# %%
#Python Extract Table from Pdf

# %%
from tabula import read_pdf
from tabulate import tabulate

# %%
import PyPDF2

PDFfilename = r"C:\Users\Lenovo\Downloads\2018112830.pdf" 

# Creating a PdfFileReader object
 
pfr = PyPDF2.PdfFileReader(open(PDFfilename, "rb"))
